# %% [markdown]
# <a href="https://colab.research.google.com/github/Gurmandeep-Kaur/Topsis_Pretrained_Models/blob/main/topsis_pretrained_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The complete package can be accessed at: https://pypi.org/project/Topsis-Gurmandeep-102303764/

# %%
# !pip install Topsis-Gurmandeep-102303764
# !python -m topsis_gurmandeep_102303764.topsis sample_data.csv "4,2,1,1" "+,-,-,-" output.csv
# Out:
# ...
# <frozen runpy>:128: RuntimeWarning: 'topsis_gurmandeep_102303764.topsis' found in sys.modules after import of package 'topsis_gurmandeep_102303764', but prior to execution of 'topsis_gurmandeep_102303764.topsis'; this may result in unpredictable behaviour
# TOPSIS analysis completed successfully.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("output.csv")

plt.bar(df["Model"], df["Topsis Score"])
plt.xticks(rotation=20)
plt.title("TOPSIS Scores for Conversational Models")

plt.show()
